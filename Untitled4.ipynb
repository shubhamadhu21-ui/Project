# %%
print("\n=== Process Only Good Yields ===")
yields = [350, -5 , 2800, 1, 3000]  # -5 and 1 are errors

for y in yields:
    if y <= 1:
        print(f"  Skipping invalid value: {y}")
        continue
    print(f"  Processing valid yield: {y} kg")
# Out:
# === Process Only Good Yields ===
#   Processing valid yield: 350 kg
#   Skipping invalid value: -5
#   Processing valid yield: 2800 kg
#   Skipping invalid value: 1
#   Processing valid yield: 3000 kg

# %%
print("\n=== disease search ===")
p", "infected", "healthy", "healthy"]

for i, status in enumerate(plants):
    print(f"Checking plant {i+1}: {status}")
    if status == "infected":
        print("⚠️ ALERT! Infected plant found. Stopping search.")
        break
# Out:
# === Pest Search ===
# Checking plant 1: healthy
# Checking plant 2: healthy
# Checking plant 3: infected
# ⚠️ ALERT! Infected plant found. Stopping search.

# %%
print("\n=== disease Search  = ["fungus", "virus","downy mildew", "rust", "healthy"]

for i, status in enumerate(crop):
    print(f"Checking plant {i+1}: {status}")
    if status == "healthy":
        print("⚠️ ALERT! Infected plant found. Stopping search.")
        break
# Out:
# === disease Search ===
# Checking plant 1: fungus
# Checking plant 2: virus
# Checking plant 3: downy mildew
# Checking plant 4: rust
# Checking plant 5: healthy
# ⚠️ ALERT! Infected plant found. Stopping search.

# %%
fooooooooooooo
