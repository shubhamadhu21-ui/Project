# %%
file=open ("/content/agri.doc.txt","r")

# %%
content=file.read()

# %%
print(content)
# Out:
# hello I'm shubha , I am learning file handling in python

# %%
file=open("agri.doc.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello I'm shubha , I am learning file handling in python

# %%
entry=input("write your journal entry:")
with open("journal.txt","a")as f:
  f.write(entry+"\n")
