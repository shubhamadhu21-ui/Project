# %%
class crop:
    def_init_(self,name,season,expected yield)
      self.name=rice
      self.season=summer
      self.expected yield=100
# Out:
#   File "/tmp/ipython-input-3314179195.py", line 2
#     def_init_(self,name,season,expected yield)
#                                         ^
# SyntaxError: invalid syntax

# %%
rice=crop("rice,karif,5.6")
wheat=crop("wheat,rabi,6.7")
print=rice(name.rice, season.rice ,expected_yield)
print=wheat(name.wheat,season.wheat,expected yield)
# Out:
#   File "/tmp/ipython-input-3054564230.py", line 4
#     print=wheat(name.wheat,season.wheat,expected yield)
#                                                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
np.random.seed(42)

data = pd.DataFrame({
    "Crop_Yield_tons": np.random.normal(4.5, 0.8, 120),
    "Water_Usage_mm": np.random.normal(520, 90, 120),
    "Cultivation_Cost_INR": np.random.normal(38000, 7000, 120),
    "Fertilizer_kg": np.random.normal(210, 35, 120)
})

data.head()
