# %%
import pandas as pd

data = {
    "Yield_kg": [3200, 3000, 3500, 2800, 3600, 2900, 3600, 4567, 5400, 5560 ],
    "Soil_Moisture": [30, 28, 35, 25, 36, 27, 32, 38, 40, 44]
}

df = pd.DataFrame(data)
df
# Out:
#    Yield_kg  Soil_Moisture
# 0      3200             30
# 1      3000             28
# 2      3500             35
# 3      2800             25
# 4      3600             36
# 5      2900             27
# 6      3600             32
# 7      4567             38
# 8      5400             40
# 9      5560             44

# %%
import pandas as pd

data = {
    "Yield_kg": [3200, 3000, 3500, 2800, 3600, 2900, 3600, 4567, 5400, 5560 ],
    "Soil_Moisture": [30, 28, 35, 25, 36, 27, 32, 38, 40, 44]
}

df = pd.DataFrame(data)
df
# Out:
#    Yield_kg  Soil_Moisture
# 0      3200             30
# 1      3000             28
# 2      3500             35
# 3      2800             25
# 4      3600             36
# 5      2900             27
# 6      3600             32
# 7      4567             38
# 8      5400             40
# 9      5560             44

# %%
import pandas as pd

data = {
    "Yield_kg": [3200, 3000, 3500, 2800, 3600, 2900, 3600, 4567, 5400, 5560 ],
    "Soil_Moisture": [30, 28, 35, 25, 36, 27, 32, 38, 40, 44]
}

df = pd.DataFrame(data)
df
# Out:
#    Yield_kg  Soil_Moisture
# 0      3200             30
# 1      3000             28
# 2      3500             35
# 3      2800             25
# 4      3600             36
# 5      2900             27
# 6      3600             32
# 7      4567             38
# 8      5400             40
# 9      5560             44

# %%
import pandas as pd

data = {
    "Yield_kg": [3200, 3000, 3500, 2800, 3600, 2900, 3600, 4567, 5400, 5560 ],
    "Soil_Moisture": [30, 28, 35, 25, 36, 27, 32, 38, 40, 44]
}

df = pd.DataFrame(data)
df
# Out:
#    Yield_kg  Soil_Moisture
# 0      3200             30
# 1      3000             28
# 2      3500             35
# 3      2800             25
# 4      3600             36
# 5      2900             27
# 6      3600             32
# 7      4567             38
# 8      5400             40
# 9      5560             44

# %%
new_data = {
    "Yield_kg": [3100, 3300, 3400, 4000, 4200],
    "Soil_Moisture": [29, 31, 33, 37, 39]
}

new_df = pd.DataFrame(new_data)
df = pd.concat([df, new_df], ignore_index=True)
df
# Out:
#     Yield_kg  Soil_Moisture
# 0       3200             30
# 1       3000             28
# 2       3500             35
# 3       2800             25
# 4       3600             36
# 5       2900             27
# 6       3600             32
# 7       4567             38
# 8       5400             40
# 9       5560             44
# 10      3100             29
# 11      3300             31
# 12      3400             33
# 13      4000             37
# 14      4200             39
# 15      3100             29
# 16      3300             31
# 17      3400             33
# 18      4000             37
# 19      4200             39

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# Sample data (for example: crop yield vs rainfall)
X = np.array([
    [10, 20],
    [12, 22],
    [11, 21],
    [30, 35],
    [32, 34],
    [31, 36],
    [50, 60],
    [52, 61],
    [51, 59]
])

# Apply K-Means
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)

# Get cluster labels and centroids
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200)

plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means Clustering Example")

plt.show()

# %%
import pandas as pd

data = {
    "Yield_kg": [3200, 3000, 3500, 2800, 3600, 2900, 3600, 4567, 5400, 5560 ],
    "Soil_Moisture": [30, 28, 35, 25, 36, 27, 32, 38, 40, 44]
}

df = pd.DataFrame(data)
df
# Out:
#    Yield_kg  Soil_Moisture
# 0      3200             30
# 1      3000             28
# 2      3500             35
# 3      2800             25
# 4      3600             36
# 5      2900             27
# 6      3600             32
# 7      4567             38
# 8      5400             40
# 9      5560             44

# %%
import pandas as pd

data = {
    "Yield_kg": [3200, 3000, 3500, 2800, 3600, 2900, 3600, 4567, 5400, 5560 ],
    "Soil_Moisture": [30, 28, 35, 25, 36, 27, 32, 38, 40, 44]
}

df = pd.DataFrame(data)
df
# Out:
#    Yield_kg  Soil_Moisture
# 0      3200             30
# 1      3000             28
# 2      3500             35
# 3      2800             25
# 4      3600             36
# 5      2900             27
# 6      3600             32
# 7      4567             38
# 8      5400             40
# 9      5560             44

# %%
import numpy as np

plots = np.array([30, 28, 35, 25, 36, 27, 32, 38, 40, 44])
center = 30

plots - center
# Out:
# array([ 0, -2,  5, -5,  6, -3,  2,  8, 10, 14])

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
df["Zone"] = kmeans.fit_predict(df)
df
# Out:
#    Yield_kg  Soil_Moisture  Zone
# 0      3200             30     2
# 1      3000             28     0
# 2      3500             35     2
# 3      2800             25     0
# 4      3600             36     2
# 5      2900             27     0
# 6      3600             32     2
# 7      4567             38     1
# 8      5400             40     1
# 9      5560             44     1

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Yield_kg"], df["Soil_Moisture"], c=df["Zone"])
plt.xlabel("Yield (kg)")
plt.ylabel("Soil Moisture")
plt.title("Farm Field Clustering")
plt.show()
