# %%
print("Column-wise Traversal:")
rows = len(result)
cols = len(result[0])

for j in range(cols):
    for i in range(rows):
        print(result[i][j], end=" ")
print("\n")
# Out:
# Column-wise Traversal:
# 8 8 8 8
