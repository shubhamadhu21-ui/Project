# %%
import statistics as stats

numbers=[10,20,30,40,50]
mean_value=stats.mean(numbers)
median_value=stats.median(numbers)
stdev_value=stats.pstdev(numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4096830049.py in <cell line: 0>()
#       1 numbers=[10,20,30,40,50]
# ----> 2 mean_value=mean(numbers)
#       3 median_value=median(numbers)
#       4 stdev_value=pstdev(numbers)
#
# NameError: name 'mean' is not defined

# %%
print("mean:",mean_value)
print("median:",median_value)
print("std Dev:",stdev_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-72626.py in <cell line: 0>()
# ----> 1 print("mean:",mean_value)
#       2 print("median:",median_value)
#       3 print("std Dev:",stdev_value)
#
# NameError: name 'mean_value' is not defined
